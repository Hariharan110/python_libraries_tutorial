# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
data=files.upload()
# Out:
#      <input type="file" id="files-c6c1252f-adf4-43e7-913e-c92024a4c63a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c6c1252f-adf4-43e7-913e-c92024a4c63a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#converting raw data into dataframe

df=pd.read_csv('cars.csv')


#  df=pd.read_csv('cars.csv',index_col= ['car_name'])

# %%
import matplotlib.pyplot as plt
df
# Out:
#                         car_name  reviews_count fuel_type  \
# 0                Maruti Alto K10             51    Petrol
# 1                  Maruti Brezza             86    Petrol
# 2                  Mahindra Thar            242    Diesel
# 3                Mahindra XUV700            313    Diesel
# 4             Mahindra Scorpio-N            107    Diesel
# ..                           ...            ...       ...
# 198     Mercedes-Benz AMG A 45 S             35    Petrol
# 199  BMW 3 Series Gran Limousine              3    Petrol
# 200               MG Hector Plus              2    Diesel
# 201                   Audi RS Q8              9    Petrol
# 202         Maruti Alto 800 tour              4    Petrol
#
#      engine_displacement  no_cylinder  seating_capacity transmission_type  \
# 0                    998            3               5.0         Automatic
# 1                   1462            4               5.0         Automatic
# ...

# %%
df.shape  # row and column
# Out:
# (203, 16)

# %%
df.info() # summary of dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203 entries, 0 to 202
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   car_name             203 non-null    object
#  1   reviews_count        203 non-null    int64
#  2   fuel_type            203 non-null    object
#  3   engine_displacement  203 non-null    int64
#  4   no_cylinder          203 non-null    int64
#  5   seating_capacity     202 non-null    float64
#  6   transmission_type    203 non-null    object
#  7   fuel_tank_capacity   203 non-null    float64
#  8   body_type            203 non-null    object
#  9   rating               203 non-null    float64
#  10  starting_price       203 non-null    int64
#  11  ending_price         203 non-null    int64
#  12  max_torque_nm        203 non-null    float64
#  13  max_torque_rpm       203 non-null    int64
#  14  max_power_bhp        203 non-null    float64
# ...

# %%
df.describe() #statistical report of data frame
# Out:
#        reviews_count  engine_displacement  no_cylinder  seating_capacity  \
# count     203.000000           203.000000   203.000000        202.000000
# mean      118.684729          2305.921182     4.709360          5.014851
# std       314.331318          1493.837786     2.538664          1.161050
# min         1.000000             0.000000     0.000000          2.000000
# 25%         5.000000          1339.500000     4.000000          5.000000
# 50%        14.000000          1991.000000     4.000000          5.000000
# 75%        83.000000          2996.000000     6.000000          5.000000
# max      2392.000000          6750.000000    12.000000          8.000000
#
#        fuel_tank_capacity      rating  starting_price  ending_price  \
# count          203.000000  203.000000    2.030000e+02  2.030000e+02
# mean            46.143842    4.433498    9.443640e+06  1.112005e+07
# std             28.904207    0.280136    1.357035e+07  1.551746e+07
# ...

# %%
df.head(4) #first 4 index value
# Out:
#           car_name  reviews_count fuel_type  engine_displacement  no_cylinder  \
# 0  Maruti Alto K10             51    Petrol                  998            3
# 1    Maruti Brezza             86    Petrol                 1462            4
# 2    Mahindra Thar            242    Diesel                 2184            4
# 3  Mahindra XUV700            313    Diesel                 2198            4
#
#    seating_capacity transmission_type  fuel_tank_capacity  body_type  rating  \
# 0               5.0         Automatic                27.0  Hatchback     4.5
# 1               5.0         Automatic                48.0        SUV     4.5
# 2               4.0         Automatic                57.0        SUV     4.5
# 3               7.0         Automatic                60.0        SUV     4.5
#
#    starting_price  ending_price  max_torque_nm  max_torque_rpm  max_power_bhp  \
# 0          399000        583000           89.0            3500          65.71
# ...

# %%
df.tail(6)  #last 6 index value
# Out:
#                         car_name  reviews_count fuel_type  \
# 197                Jeep Meridian             78    Diesel
# 198     Mercedes-Benz AMG A 45 S             35    Petrol
# 199  BMW 3 Series Gran Limousine              3    Petrol
# 200               MG Hector Plus              2    Diesel
# 201                   Audi RS Q8              9    Petrol
# 202         Maruti Alto 800 tour              4    Petrol
#
#      engine_displacement  no_cylinder  seating_capacity transmission_type  \
# 197                 1956            4               7.0         Automatic
# 198                 1991            4               5.0         Automatic
# 199                 1998            4               5.0         Automatic
# 200                 1956            4               7.0            Manual
# 201                 3998            8               5.0         Automatic
# 202                  796            3               5.0            Manual
#
# ...

# %%
***************************************************************************************************************************************************************
***************************************************************************************************************************************************************

# %% [markdown]
# **accesing & indexing & sling----------**

# %%
# accesing the column values
df['car_name']
# Out:
# 0                  Maruti Alto K10
# 1                    Maruti Brezza
# 2                    Mahindra Thar
# 3                  Mahindra XUV700
# 4               Mahindra Scorpio-N
#                   ...
# 198       Mercedes-Benz AMG A 45 S
# 199    BMW 3 Series Gran Limousine
# 200                 MG Hector Plus
# 201                     Audi RS Q8
# 202           Maruti Alto 800 tour
# Name: car_name, Length: 203, dtype: object

# %%
df[["car_name",'fuel_type']]
# Out:
#                         car_name fuel_type
# 0                Maruti Alto K10    Petrol
# 1                  Maruti Brezza    Petrol
# 2                  Mahindra Thar    Diesel
# 3                Mahindra XUV700    Diesel
# 4             Mahindra Scorpio-N    Diesel
# ..                           ...       ...
# 198     Mercedes-Benz AMG A 45 S    Petrol
# 199  BMW 3 Series Gran Limousine    Petrol
# 200               MG Hector Plus    Diesel
# 201                   Audi RS Q8    Petrol
# 202         Maruti Alto 800 tour    Petrol
#
# [203 rows x 2 columns]

# %%
#error
df[4]
df=pd.read_csv('cars.csv',index_col= ['car_name'])
df['Mahindra Thar']
# we cant acces row in this method
# Out:
# reviews_count                242
# fuel_type                 Diesel
# engine_displacement         2184
# no_cylinder                    4
# seating_capacity             4.0
# transmission_type      Automatic
# fuel_tank_capacity          57.0
# body_type                    SUV
# rating                       4.5
# starting_price           1353000
# ending_price             1603000
# max_torque_nm              300.0
# max_torque_rpm              2800
# max_power_bhp              130.0
# max_power_rp                3750
# Name: Mahindra Thar, dtype: object

# %%
df[2:4] #df[2:4] == df.iloc[2:4]
# Out:
#                  reviews_count fuel_type  engine_displacement  no_cylinder  \
# car_name
# Mahindra Thar              242    Diesel                 2184            4
# Mahindra XUV700            313    Diesel                 2198            4
#
#                  seating_capacity transmission_type  fuel_tank_capacity  \
# car_name
# Mahindra Thar                 4.0         Automatic                57.0
# Mahindra XUV700               7.0         Automatic                60.0
#
#                 body_type  rating  starting_price  ending_price  \
# car_name
# Mahindra Thar         SUV     4.5         1353000       1603000
# Mahindra XUV700       SUV     4.5         1318000       2458000
#
#                  max_torque_nm  max_torque_rpm  max_power_bhp  max_power_rp
# car_name
# Mahindra Thar            300.0            2800         130.00          3750
# Mahindra XUV700          450.0            2800         182.38          3500

# %%
df.loc[4] #index the row value
# Out:
# car_name               Mahindra Scorpio-N
# reviews_count                         107
# fuel_type                          Diesel
# engine_displacement                  2198
# no_cylinder                             4
# seating_capacity                      7.0
# transmission_type               Automatic
# fuel_tank_capacity                   57.0
# body_type                             SUV
# rating                                4.5
# starting_price                    1199000
# ending_price                      2390000
# max_torque_nm                       400.0
# max_torque_rpm                       2750
# max_power_bhp                      172.45
# max_power_rp                         3500
# Name: 4, dtype: object

# %%
df.iloc[4] #located the index value print the columns
# Out:
# car_name               Mahindra Scorpio-N
# reviews_count                         107
# fuel_type                          Diesel
# engine_displacement                  2198
# no_cylinder                             4
# seating_capacity                      7.0
# transmission_type               Automatic
# fuel_tank_capacity                   57.0
# body_type                             SUV
# rating                                4.5
# starting_price                    1199000
# ending_price                      2390000
# max_torque_nm                       400.0
# max_torque_rpm                       2750
# max_power_bhp                      172.45
# max_power_rp                         3500
# Name: 4, dtype: object

# %%
df.iloc[0:4] #slicing with row value   ** iloc medhoe execute as (n,n-1)
# Out:
#           car_name  reviews_count fuel_type  engine_displacement  no_cylinder  \
# 0  Maruti Alto K10             51    Petrol                  998            3
# 1    Maruti Brezza             86    Petrol                 1462            4
# 2    Mahindra Thar            242    Diesel                 2184            4
# 3  Mahindra XUV700            313    Diesel                 2198            4
#
#    seating_capacity transmission_type  fuel_tank_capacity  body_type  rating  \
# 0               5.0         Automatic                27.0  Hatchback     4.5
# 1               5.0         Automatic                48.0        SUV     4.5
# 2               4.0         Automatic                57.0        SUV     4.5
# 3               7.0         Automatic                60.0        SUV     4.5
#
#    starting_price  ending_price  max_torque_nm  max_torque_rpm  max_power_bhp  \
# 0          399000        583000           89.0            3500          65.71
# ...

# %%
df.loc[0:4]  #slicing with row value   ** loc medhoe execute as (n,n)
# Out:
#              car_name  reviews_count fuel_type  engine_displacement  \
# 0     Maruti Alto K10             51    Petrol                  998
# 1       Maruti Brezza             86    Petrol                 1462
# 2       Mahindra Thar            242    Diesel                 2184
# 3     Mahindra XUV700            313    Diesel                 2198
# 4  Mahindra Scorpio-N            107    Diesel                 2198
#
#    no_cylinder  seating_capacity transmission_type  fuel_tank_capacity  \
# 0            3               5.0         Automatic                27.0
# 1            4               5.0         Automatic                48.0
# 2            4               4.0         Automatic                57.0
# 3            4               7.0         Automatic                60.0
# 4            4               7.0         Automatic                57.0
#
#    body_type  rating  starting_price  ending_price  max_torque_nm  \
# ...

# %%
#slicing specified values usinf------loc[]
# we cant slicing column ["str","str","str"]
# if we want to acces slicing with column name
df.loc[1:4,1:5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-cfdb017718b9> in <cell line: 4>()
#       2 # we cant indexing with accesing column ["str","str","str"]
#       3 # if we want to acces slicing with column name
# ----> 4 df.loc[1:4,1:5]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1254             return self._multi_take(tup)
#    1255
# -> 1256         return self._getitem_tuple_same_dim(tup)
#    1257
# ...

# %%
df.loc[1:4,"car_name","no_cylinder"]
# Out:
#              car_name  reviews_count fuel_type  engine_displacement  \
# 1       Maruti Brezza             86    Petrol                 1462
# 2       Mahindra Thar            242    Diesel                 2184
# 3     Mahindra XUV700            313    Diesel                 2198
# 4  Mahindra Scorpio-N            107    Diesel                 2198
#
#    no_cylinder
# 1            4
# 2            4
# 3            4
# 4            4

# %%
df.loc[1:4,"car_name":"no_cylinder"]
# Out:
#              car_name  reviews_count fuel_type  engine_displacement  \
# 1       Maruti Brezza             86    Petrol                 1462
# 2       Mahindra Thar            242    Diesel                 2184
# 3     Mahindra XUV700            313    Diesel                 2198
# 4  Mahindra Scorpio-N            107    Diesel                 2198
#
#    no_cylinder
# 1            4
# 2            4
# 3            4
# 4            4

# %%
df.loc[1:4,["car_name","no_cylinder"]]
# Out:
#              car_name  no_cylinder
# 1       Maruti Brezza            4
# 2       Mahindra Thar            4
# 3     Mahindra XUV700            4
# 4  Mahindra Scorpio-N            4

# %%
df.loc[:,"car_name":"no_cylinder"] #slicing column
# Out:
#                         car_name  reviews_count fuel_type  \
# 0                Maruti Alto K10             51    Petrol
# 1                  Maruti Brezza             86    Petrol
# 2                  Mahindra Thar            242    Diesel
# 3                Mahindra XUV700            313    Diesel
# 4             Mahindra Scorpio-N            107    Diesel
# ..                           ...            ...       ...
# 198     Mercedes-Benz AMG A 45 S             35    Petrol
# 199  BMW 3 Series Gran Limousine              3    Petrol
# 200               MG Hector Plus              2    Diesel
# 201                   Audi RS Q8              9    Petrol
# 202         Maruti Alto 800 tour              4    Petrol
#
#      engine_displacement  no_cylinder
# 0                    998            3
# 1                   1462            4
# 2                   2184            4
# 3                   2198            4
# 4                   2198            4
# ...

# %%
#slicing specified values usinf------iloc[]
# we cant slicing with column name
# if we want to acces with index value
df.iloc[1:4,"car_name","no_cylinder"]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-14-58062f48c724> in <cell line: 4>()
#       2 # we cant slicing with column name
#       3 # if we want to acces with index value
# ----> 4 df.iloc[1:4,"car_name","no_cylinder"]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1561     def _getitem_tuple(self, tup: tuple):
#    1562
# -> 1563         tup = self._validate_tuple_indexer(tup)
#    1564         with suppress(IndexingError):
# ...

# %%
df.iloc[1:4,0:5]
# Out:
#           car_name  reviews_count fuel_type  engine_displacement  no_cylinder
# 1    Maruti Brezza             86    Petrol                 1462            4
# 2    Mahindra Thar            242    Diesel                 2184            4
# 3  Mahindra XUV700            313    Diesel                 2198            4

# %%
df.iloc[1:4,1:6] #indexing in row and soloumn
# Out:
#    reviews_count fuel_type  engine_displacement  no_cylinder  seating_capacity
# 1             86    Petrol                 1462            4               5.0
# 2            242    Diesel                 2184            4               4.0
# 3            313    Diesel                 2198            4               7.0

# %%
**************************************************************************************************************************************************************
***************************************************************************************************************************************************************

# %%
# null value as boolean
df.isnull()

# %%
# sum of null value
df.isnull().sum()
# Out:
# car_name               0
# reviews_count          0
# fuel_type              0
# engine_displacement    0
# no_cylinder            0
# seating_capacity       1
# transmission_type      0
# fuel_tank_capacity     0
# body_type              0
# rating                 0
# starting_price         0
# ending_price           0
# max_torque_nm          0
# max_torque_rpm         0
# max_power_bhp          0
# max_power_rp           0
# dtype: int64

# %%
# locate the null value where it is? .any(axis=1)

loc_null=df[df.isnull().any(axis=1)]
loc_null
# Out:
#        car_name  reviews_count fuel_type  engine_displacement  no_cylinder  \
# 143  Mclaren GT              1    Petrol                 3994            8
#
#      seating_capacity transmission_type  fuel_tank_capacity body_type  rating  \
# 143               NaN         Automatic                72.0     Coupe     4.5
#
#      starting_price  ending_price  max_torque_nm  max_torque_rpm  \
# 143        45000000      45000000          630.0               0
#
#      max_power_bhp  max_power_rp
# 143         611.51             0

# %%
# check ... null value or not

df.loc[143,'seating_capacity']
# Out:
# nan

# %%
# put value for null
df.fillna(9.0, inplace=True)
df.isnull().sum()
# Out:
# car_name               0
# reviews_count          0
# fuel_type              0
# engine_displacement    0
# no_cylinder            0
# seating_capacity       0
# transmission_type      0
# fuel_tank_capacity     0
# body_type              0
# rating                 0
# starting_price         0
# ending_price           0
# max_torque_nm          0
# max_torque_rpm         0
# max_power_bhp          0
# max_power_rp           0
# dtype: int64
