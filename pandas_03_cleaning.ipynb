# %%
import pandas as pd

# %%
from google.colab import files
data=files.upload

# %%
data = {
    'Name': ['John Doe', 'Jane Smith', 'Sam Johnson', 'Emily Williams', 'Michael Lee'],
    'Age': [25, 32, None, 45, None],
    'Gender': ['M', 'F', 'M', 'F', '-'],
    'Email': ['john@example.com', 'jane@example.com', 'sam.example.com', '', 'michael@example.com'],
    'Phone': ['123-456-7890', '555-555-5555', '999-123-4567', '444-789-1234', '']
}
df = pd.DataFrame(data)

# %%
df.isnull()
# Out:
#     Name    Age  Gender  Email  Phone
# 0  False  False   False  False  False
# 1  False  False   False  False  False
# 2  False   True   False  False  False
# 3  False  False   False  False  False
# 4  False   True   False  False  False
