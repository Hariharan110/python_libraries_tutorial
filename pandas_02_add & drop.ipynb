# %%
import pandas as pd

# %% [markdown]
# 1. add column & row
# 2. drop column & row

# %%
from google.colab import files
data1=files.upload()
# Out:
#      <input type="file" id="files-74e25344-9f8f-4713-89c7-03bfb5a4b2d2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-74e25344-9f8f-4713-89c7-03bfb5a4b2d2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('example.csv')
df
# Out:
#     Hours  sHours  Marks     m1   m2  m3
# 0       0       6     34   78.0   89  98
# 1       1       7     36   67.5   90  92
# 2       1       6     33   57.0   91  86
# 3       1       8     39   46.5   92  80
# 4       1       8     42   36.0   93  74
# 5       2       8     45   25.5   94  68
# 6       2       6     38   15.0   95  62
# 7       3       6     45    4.5   96  56
# 8       3       7     53   -6.0   97  50
# 9       3       7     46  -16.5   98  44
# 10      3       8     56  -27.0   99  38
# 11      4       8     59  -37.5  100  32
# 12      4       7     55  -48.0  101  26
# 13      4       7     56  -58.5  102  20
# 14      5       8     72  -69.0  103  14
# 15      5       6     59  -79.5  104   8
# 16      6       6     62  -90.0  105   2
# 17      6       7     71 -100.5  106  -4
# 18      7       8     78 -111.0  107 -10
# 19      7       8     88 -121.5  108 -16
# 20      7       6     61 -132.0  109 -22
# 21      7       6     74 -142.5  110 -28
# ...

# %%
# add row    --append()
new_row={'Hours':11,	'sHours':12 ,	'Marks':11,	'm1':12	,'m2':12,	'm3':12}
df= df.append(new_row, ignore_index=True)
df
# Out:
# <ipython-input-4-921ea1166e8b>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df= df.append(new_row, ignore_index=True)
#     Hours  sHours  Marks     m1   m2  m3
# 0       0       6     34   78.0   89  98
# 1       1       7     36   67.5   90  92
# 2       1       6     33   57.0   91  86
# 3       1       8     39   46.5   92  80
# 4       1       8     42   36.0   93  74
# 5       2       8     45   25.5   94  68
# 6       2       6     38   15.0   95  62
# 7       3       6     45    4.5   96  56
# 8       3       7     53   -6.0   97  50
# 9       3       7     46  -16.5   98  44
# 10      3       8     56  -27.0   99  38
# 11      4       8     59  -37.5  100  32
# 12      4       7     55  -48.0  101  26
# 13      4       7     56  -58.5  102  20
# 14      5       8     72  -69.0  103  14
# 15      5       6     59  -79.5  104   8
# 16      6       6     62  -90.0  105   2
# ...

# %%
# add column
df['total']=df['m1']+df['m2']+df['m3']
df
# Out:
#     Hours  sHours  Marks     m1   m2  m3  total
# 0       0       6     34   78.0   89  98  265.0
# 1       1       7     36   67.5   90  92  249.5
# 2       1       6     33   57.0   91  86  234.0
# 3       1       8     39   46.5   92  80  218.5
# 4       1       8     42   36.0   93  74  203.0
# 5       2       8     45   25.5   94  68  187.5
# 6       2       6     38   15.0   95  62  172.0
# 7       3       6     45    4.5   96  56  156.5
# 8       3       7     53   -6.0   97  50  141.0
# 9       3       7     46  -16.5   98  44  125.5
# 10      3       8     56  -27.0   99  38  110.0
# 11      4       8     59  -37.5  100  32   94.5
# 12      4       7     55  -48.0  101  26   79.0
# 13      4       7     56  -58.5  102  20   63.5
# 14      5       8     72  -69.0  103  14   48.0
# 15      5       6     59  -79.5  104   8   32.5
# 16      6       6     62  -90.0  105   2   17.0
# 17      6       7     71 -100.5  106  -4    1.5
# 18      7       8     78 -111.0  107 -10  -14.0
# ...

# %%
# drop row

df_dr= 1                     #index value
df_drp_row= df.drop(df1_dr)  # (or)  df.drop(1)
df_drp_row

# [1] index droped

# %%
df.drop_dipicate() #it will remove dupicaate rows

# %%
# drop column

drop_col= df.drop('total', axis=1)
drop_col

# 'total col droped

# %%
# change column value as row value (or)
# set new index ------- df.set_index()

new_index = df.set_index('Marks')
new_index

# (or)
# new = 'Marks'
# new_index = df.set_index( new )

# %%
new_index.reset_index()
# Out:
#     Marks  Hours  sHours     m1   m2  m3  total
# 0      34      0       6   78.0   89  98  265.0
# 1      36      1       7   67.5   90  92  249.5
# 2      33      1       6   57.0   91  86  234.0
# 3      39      1       8   46.5   92  80  218.5
# 4      42      1       8   36.0   93  74  203.0
# 5      45      2       8   25.5   94  68  187.5
# 6      38      2       6   15.0   95  62  172.0
# 7      45      3       6    4.5   96  56  156.5
# 8      53      3       7   -6.0   97  50  141.0
# 9      46      3       7  -16.5   98  44  125.5
# 10     56      3       8  -27.0   99  38  110.0
# 11     59      4       8  -37.5  100  32   94.5
# 12     55      4       7  -48.0  101  26   79.0
# 13     56      4       7  -58.5  102  20   63.5
# 14     72      5       8  -69.0  103  14   48.0
# 15     59      5       6  -79.5  104   8   32.5
# 16     62      6       6  -90.0  105   2   17.0
# 17     71      6       7 -100.5  106  -4    1.5
# 18     78      7       8 -111.0  107 -10  -14.0
# ...

# %%
# drop row value after set index
new_index.drop(33, axis=0)

# %%
df['Hours']>6
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# Name: Hours, dtype: bool

# %%
 df[(df['Hours'] > 3) & (df['Marks'] > 80)]
# Out:
#     Hours  sHours  Marks     m1   m2  m3
# 19      7       8     88 -121.5  108 -16
# 23      8       8     89 -163.5  112 -40
# 24      9       8     82 -174.0  113 -46
# 26      9       8     89 -195.0  115 -58
# 27     10       8     81 -205.5  116 -64
# 28     10       8     82 -216.0  117 -70

# %%
***********************************************************************************************************************************************
**********************************************************************************************************************************************

# %% [markdown]
# **Grouby and aggreation**

# %%
df
# Out:
#     Hours  sHours  Marks     m1   m2  m3
# 0       0       6     34   78.0   89  98
# 1       1       7     36   67.5   90  92
# 2       1       6     33   57.0   91  86
# 3       1       8     39   46.5   92  80
# 4       1       8     42   36.0   93  74
# 5       2       8     45   25.5   94  68
# 6       2       6     38   15.0   95  62
# 7       3       6     45    4.5   96  56
# 8       3       7     53   -6.0   97  50
# 9       3       7     46  -16.5   98  44
# 10      3       8     56  -27.0   99  38
# 11      4       8     59  -37.5  100  32
# 12      4       7     55  -48.0  101  26
# 13      4       7     56  -58.5  102  20
# 14      5       8     72  -69.0  103  14
# 15      5       6     59  -79.5  104   8
# 16      6       6     62  -90.0  105   2
# 17      6       7     71 -100.5  106  -4
# 18      7       8     78 -111.0  107 -10
# 19      7       8     88 -121.5  108 -16
# 20      7       6     61 -132.0  109 -22
# 21      7       6     74 -142.5  110 -28
# ...

# %%
# groub 'hours' columns that mean groub the same values in 'hours'
# grouby and aggrecreation

df1=df.groupby("Hours")
df1

# %%
# how many values are there ex- 1 value is 4 time repeated in 'hours'
df1.count()
# Out:
#        sHours  Marks  m1  m2  m3
# Hours
# 0           1      1   1   1   1
# 1           4      4   4   4   4
# 2           2      2   2   2   2
# 3           4      4   4   4   4
# 4           3      3   3   3   3
# 5           2      2   2   2   2
# 6           2      2   2   2   2
# 7           4      4   4   4   4
# 8           2      2   2   2   2
# 9           3      3   3   3   3
# 10          2      2   2   2   2
# 11          1      1   1   1   1

# %%
df1.describe()

# (or)   df.grouby('Hours').describe()
# Out:
#       sHours                                                Marks             \
#        count      mean       std  min   25%  50%   75%  max count       mean
# Hours
# 0        1.0  6.000000       NaN  6.0  6.00  6.0  6.00  6.0   1.0  34.000000
# 1        4.0  7.250000  0.957427  6.0  6.75  7.5  8.00  8.0   4.0  37.500000
# 2        2.0  7.000000  1.414214  6.0  6.50  7.0  7.50  8.0   2.0  41.500000
# 3        4.0  7.000000  0.816497  6.0  6.75  7.0  7.25  8.0   4.0  50.000000
# 4        3.0  7.333333  0.577350  7.0  7.00  7.0  7.50  8.0   3.0  56.666667
# 5        2.0  7.000000  1.414214  6.0  6.50  7.0  7.50  8.0   2.0  65.500000
# 6        2.0  6.500000  0.707107  6.0  6.25  6.5  6.75  7.0   2.0  66.500000
# 7        4.0  7.000000  1.154701  6.0  6.00  7.0  8.00  8.0   4.0  75.250000
# 8        2.0  7.500000  0.707107  7.0  7.25  7.5  7.75  8.0   2.0  80.000000
# 9        3.0  7.000000  1.732051  5.0  6.50  8.0  8.00  8.0   3.0  79.333333
# ...

# %%
df1.min()
# Out:
#        sHours  Marks     m1   m2  m3
# Hours
# 0           6     34   78.0   89  98
# 1           6     33   36.0   90  74
# 2           6     38   15.0   94  62
# 3           6     45  -27.0   96  38
# 4           7     55  -58.5  100  20
# 5           6     59  -79.5  103   8
# 6           6     62 -100.5  105  -4
# 7           6     61 -142.5  107 -28
# 8           7     71 -163.5  111 -40
# 9           5     67 -195.0  113 -58
# 10          8     81 -216.0  116 -70
# 11          7     79 -226.5  118 -76

# %%
df1.max()
# Out:
#        sHours  Marks     m1   m2  m3
# Hours
# 0           6     34   78.0   89  98
# 1           8     42   67.5   93  92
# 2           8     45   25.5   95  68
# 3           8     56    4.5   99  56
# 4           8     59  -37.5  102  32
# 5           8     72  -69.0  104  14
# 6           7     71  -90.0  106   2
# 7           8     88 -111.0  110 -10
# 8           8     89 -153.0  112 -34
# 9           8     89 -174.0  115 -46
# 10          8     82 -205.5  117 -64
# 11          7     79 -226.5  118 -76

# %%
df1.mean()
# Out:
#          sHours      Marks      m1     m2    m3
# Hours
# 0      6.000000  34.000000   78.00   89.0  98.0
# 1      7.250000  37.500000   51.75   91.5  83.0
# 2      7.000000  41.500000   20.25   94.5  65.0
# 3      7.000000  50.000000  -11.25   97.5  47.0
# 4      7.333333  56.666667  -48.00  101.0  26.0
# 5      7.000000  65.500000  -74.25  103.5  11.0
# 6      6.500000  66.500000  -95.25  105.5  -1.0
# 7      7.000000  75.250000 -126.75  108.5 -19.0
# 8      7.500000  80.000000 -158.25  111.5 -37.0
# 9      7.000000  79.333333 -184.50  114.0 -52.0
# 10     8.000000  81.500000 -210.75  116.5 -67.0
# 11     7.000000  79.000000 -226.50  118.0 -76.0

# %%
df1.median()
# Out:
#        sHours  Marks      m1     m2    m3
# Hours
# 0         6.0   34.0   78.00   89.0  98.0
# 1         7.5   37.5   51.75   91.5  83.0
# 2         7.0   41.5   20.25   94.5  65.0
# 3         7.0   49.5  -11.25   97.5  47.0
# 4         7.0   56.0  -48.00  101.0  26.0
# 5         7.0   65.5  -74.25  103.5  11.0
# 6         6.5   66.5  -95.25  105.5  -1.0
# 7         7.0   76.0 -126.75  108.5 -19.0
# 8         7.5   80.0 -158.25  111.5 -37.0
# 9         8.0   82.0 -184.50  114.0 -52.0
# 10        8.0   81.5 -210.75  116.5 -67.0
# 11        7.0   79.0 -226.50  118.0 -76.0

# %%
df1.mode()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-9bd0b72e1701> in <cell line: 1>()
# ----> 1 df1.mode()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     985             return self[attr]
#     986
# --> 987         raise AttributeError(
#     988             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     989         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'mode'

# %%
df1.std()
# Out:
#          sHours      Marks         m1        m2        m3
# Hours
# 0           NaN        NaN        NaN       NaN       NaN
# 1      0.957427   3.872983  13.555442  1.290994  7.745967
# 2      1.414214   4.949747   7.424621  0.707107  4.242641
# 3      0.816497   5.354126  13.555442  1.290994  7.745967
# 4      0.577350   2.081666  10.500000  1.000000  6.000000
# 5      1.414214   9.192388   7.424621  0.707107  4.242641
# 6      0.707107   6.363961   7.424621  0.707107  4.242641
# 7      1.154701  11.176612  13.555442  1.290994  7.745967
# 8      0.707107  12.727922   7.424621  0.707107  4.242641
# 9      1.732051  11.239810  10.500000  1.000000  6.000000
# 10     0.000000   0.707107   7.424621  0.707107  4.242641
# 11          NaN        NaN        NaN       NaN       NaN

# %%
# Out:
#       sHours                                                Marks             \
#        count      mean       std  min   25%  50%   75%  max count       mean
# Hours
# 0        1.0  6.000000       NaN  6.0  6.00  6.0  6.00  6.0   1.0  34.000000
# 1        4.0  7.250000  0.957427  6.0  6.75  7.5  8.00  8.0   4.0  37.500000
# 2        2.0  7.000000  1.414214  6.0  6.50  7.0  7.50  8.0   2.0  41.500000
# 3        4.0  7.000000  0.816497  6.0  6.75  7.0  7.25  8.0   4.0  50.000000
# 4        3.0  7.333333  0.577350  7.0  7.00  7.0  7.50  8.0   3.0  56.666667
# 5        2.0  7.000000  1.414214  6.0  6.50  7.0  7.50  8.0   2.0  65.500000
# 6        2.0  6.500000  0.707107  6.0  6.25  6.5  6.75  7.0   2.0  66.500000
# 7        4.0  7.000000  1.154701  6.0  6.00  7.0  8.00  8.0   4.0  75.250000
# 8        2.0  7.500000  0.707107  7.0  7.25  7.5  7.75  8.0   2.0  80.000000
# 9        3.0  7.000000  1.732051  5.0  6.50  8.0  8.00  8.0   3.0  79.333333
# ...

# %%
****************************************************************************************************************************************************************************************************************************************************************
********************************************************************************************************************************************************************************

# %% [markdown]
# **Filtering**

# %%
df[df['Hours']>5]
# Out:
#     Hours  sHours  Marks     m1   m2  m3
# 17      6       7     71 -100.5  106  -4
# 18      7       8     78 -111.0  107 -10
# 19      7       8     88 -121.5  108 -16
# 22      8       7     71 -153.0  111 -34
# 23      8       8     89 -163.5  112 -40
# 24      9       8     82 -174.0  113 -46
# 26      9       8     89 -195.0  115 -58
# 27     10       8     81 -205.5  116 -64
# 28     10       8     82 -216.0  117 -70
# 29     11       7     79 -226.5  118 -76

# %%
df[ (df['Hours']>5) & (df['sHours'] >6) ]
# Out:
#     Hours  sHours  Marks     m1   m2  m3
# 17      6       7     71 -100.5  106  -4
# 18      7       8     78 -111.0  107 -10
# 19      7       8     88 -121.5  108 -16
# 22      8       7     71 -153.0  111 -34
# 23      8       8     89 -163.5  112 -40
# 24      9       8     82 -174.0  113 -46
# 26      9       8     89 -195.0  115 -58
# 27     10       8     81 -205.5  116 -64
# 28     10       8     82 -216.0  117 -70
# 29     11       7     79 -226.5  118 -76

# %%
df.loc[ (df['Hours']>5) & (df['sHours'] >6) ]
# Out:
#     Hours  sHours  Marks     m1   m2  m3
# 17      6       7     71 -100.5  106  -4
# 18      7       8     78 -111.0  107 -10
# 19      7       8     88 -121.5  108 -16
# 22      8       7     71 -153.0  111 -34
# 23      8       8     89 -163.5  112 -40
# 24      9       8     82 -174.0  113 -46
# 26      9       8     89 -195.0  115 -58
# 27     10       8     81 -205.5  116 -64
# 28     10       8     82 -216.0  117 -70
# 29     11       7     79 -226.5  118 -76

# %%
df[df["name"].str.contsins('h')]   # in will return name those who have 'h' letter in the name

# %%
df[df["m1"].str.contsins(3)] # only work on str values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-fe79014cf3bb> in <cell line: 1>()
# ----> 1 df[df["m1"].str.contsins(3)]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
#     184         # https://www.pydanny.com/cached-property.html
#
# ...

# %%
df[df["name"].str.startswith('h')] # it will return names start with 'h' letter

# %%
df[df["name"].str.endswith('h')]
